# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#dataset
data = pd.read_csv('final_dataset.csv')
print(data.head())
# Out:
#    Order_ID Order_Priority  Order_Quantity    Sales  Profit  \
# 0       643           High              21  2781.82  695.26
# 1      8995           High              35  3389.93  737.94
# 2      9127  Not Specified               7  2039.56  329.49
# 3     26272            Low               6   905.94    4.19
# 4     36646         Medium              24  1168.15  743.96
#
#                   Region Product_Category  \
# 0                Nunavut  Office Supplies
# 1  Northwest Territories        Furniture
# 2  Northwest Territories  Office Supplies
# 3  Northwest Territories        Furniture
# 4  Northwest Territories  Office Supplies
#
#                                         Product_Name  result
# 0              SAFCO Commercial Wire Shelving, Black       0
# 1       Luxo Professional Combination Clamp-On Lamps       1
# 2  Tennsco Snap-Together Open Shelving Units, Sta...       0
# 3                           Hon Olson Stacker Stools       0
# 4                        Tennsco Industrial Shelving       0

# %%
print(data.tail())
# Out:
#      Order_ID Order_Priority  Order_Quantity    Sales   Profit   Region  \
# 725     56101  Not Specified              44  5347.13  1886.41  Ontario
# 726      1059       Critical              22   127.33     5.30  Ontario
# 727      1059       Critical              24   990.10   310.22  Ontario
# 728      1826  Not Specified               5    28.32    14.35  Ontario
# 729     20003         Medium              39   796.08    30.29  Ontario
#
#     Product_Category                                       Product_Name  \
# 725  Office Supplies     GBC Therma-A-Bind 250T Electric Binding System
# 726  Office Supplies  Wilson Jones 14 Line Acrylic Coated Pressboard...
# 727  Office Supplies  Wilson Jones Ledger-Size, Piano-Hinge Binder, ...
# 728  Office Supplies  Hammermill CopyPlus Copy Paper (20Lb. and 84 B...
# 729       Technology                      Belkin 105-Key Black Keyboard
#
#      result
# 725       1
# 726       0
# 727       0
# 728       0
# 729       0

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          730 non-null    int64
#  1   Order_Priority    730 non-null    object
#  2   Order_Quantity    730 non-null    int64
#  3   Sales             730 non-null    float64
#  4   Profit            730 non-null    float64
#  5   Region            730 non-null    object
#  6   Product_Category  730 non-null    object
#  7   Product_Name      730 non-null    object
#  8   result            730 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 51.5+ KB
# None

# %%
df = pd.DataFrame(data)
plt.plot(df['Region'], df['Sales'], color='red', marker='o')
plt.title('Region vs Sales', fontsize=14)
plt.xlabel('Region', fontsize=14)
plt.ylabel('Sales', fontsize=14)
plt.grid(True)
plt.show()

# %%
df = pd.DataFrame(data)
plt.plot(df['Profit'], df['Product_Category'], color='red', marker='o')
plt.title('Profit vs Product_Category', fontsize=14)
plt.xlabel('Profit', fontsize=14)
plt.ylabel('Product_Category', fontsize=14)
plt.grid(True)
plt.show()

# %%
# reading the database
data = pd.read_csv("final_dataset.csv")
 
# Scatter plot with day against tip
plt.scatter(data['Sales'], data['Region'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Sales')
plt.ylabel('Region')
 
plt.show()

# %%
# reading the database
data = pd.read_csv("final_dataset.csv")
 
# Bar chart with day against tip
plt.bar(data['Product_Category'], data['Sales'])
 
plt.title("Bar Chart")
 
# Setting the X and Y labels
plt.xlabel('Product_Category')
plt.ylabel('Sales')
 
# Adding the legends
plt.show()

# %%
# reading the database
data = pd.read_csv("final_dataset.csv")
 
# histogram of total_bills
plt.hist(data['Sales'])
 
plt.title("Histogram")
 
# Adding the legends
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
 
data = pd.read_csv("final_dataset.csv")
 
sns.lineplot(x='Product_Category', y='Order_Priority', data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
 
data = pd.read_csv("final_dataset.csv")
 
sns.lineplot(x='Region', y='Order_Priority', data=data)
plt.show()
